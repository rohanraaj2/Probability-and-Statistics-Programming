# %% [markdown]
# ### Setup ###

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### [15 Marks] Task 1 : Plot Histogram ####
# The following code simulates the rolling of a fair 4-sided die 100 times and plots the histogram of the outputs.

# %%
# Simulates the roll of a a fair 4-sided die. Size determines the number of times the die is rolled. 
fair  = np.random.randint(low=1,high=5, size=100)
# Plot Histogram. 
plt.hist(fair,bins=[1,2,3,4,5],rwidth = 0.5, density=True, align='left')
plt.title("N  = %i "%100)
plt.show()

# %% [markdown]
# In this task, you need to simulate the throwing of a fair 8-sided die (Octahedron) N times and plot the corresponding histogram of outputs. You are required to experiment with different values of N and comment how the shape of the histogram changes with increasing values of N.

# %%
# YOUR CODE FOR TASK 1

# Name: Rohan Raj
# ID: rr07656

# Simulates the roll of a a fair 4-sided die. Size determines the number of times the die is rolled. 
fair  = np.random.randint(low=1,high=9, size=10)
# Plot Histogram. 
plt.hist(fair,bins=[1,2,3,4,5,6,7,8,9],rwidth = 0.5, density=True, align='left')
plt.title("N  = %i "%10)
plt.show()

# Simulates the roll of a a fair 4-sided die. Size determines the number of times the die is rolled. 
fair  = np.random.randint(low=1,high=9, size=50)
# Plot Histogram. 
plt.hist(fair,bins=[1,2,3,4,5,6,7,8,9],rwidth = 0.5, density=True, align='left')
plt.title("N  = %i "%50)
plt.show()

# Simulates the roll of a a fair 4-sided die. Size determines the number of times the die is rolled. 
fair  = np.random.randint(low=1,high=9, size=200)
# Plot Histogram. 
plt.hist(fair,bins=[1,2,3,4,5,6,7,8,9],rwidth = 0.5, density=True, align='left')
plt.title("N  = %i "%200)
plt.show()

# Simulates the roll of a a fair 4-sided die. Size determines the number of times the die is rolled. 
fair  = np.random.randint(low=1,high=9, size=400)
# Plot Histogram. 
plt.hist(fair,bins=[1,2,3,4,5,6,7,8,9],rwidth = 0.5, density=True, align='left')
plt.title("N  = %i "%400)
plt.show()

# Simulates the roll of a a fair 4-sided die. Size determines the number of times the die is rolled. 
fair  = np.random.randint(low=1,high=9, size=900)
# Plot Histogram. 
plt.hist(fair,bins=[1,2,3,4,5,6,7,8,9],rwidth = 0.5, density=True, align='left')
plt.title("N  = %i "%900)
plt.show()

# %% [markdown]
# **Comments**
#
# Rohan Raj
# rr07656
#
# As we increase the size of N, the histogram becomes more balanced. In the case where the value of N is very large, the histogram becomes more uniform. In the case where the value of N is very small, the histogram becomes more skewed.
#
# Hence, having a larger value of N gives us more accuracy in the histogram.

# %% [markdown]
# ### [10 Marks] Task 2 : Expectation and Variance ###
# In Task 1, you plotted the histogram for simulated throwing of a fair 8-sided die N times. In Task 2, you have been provided functions that compute the expectation and variance for each value of N. You are required to comment on the comparison of these calculated values with the theoretical values of expaction and variance (obtained by considering the outcome of rolling a fair 8-sided die as a Discrete Uniform Random Variable).

# %%
# Compute Expectation 
def compute_expectation (x: np.array, p: np.array ):
   return np.sum( p * x)

# Compute Variance
def compute_variance (x: np.array, p: np.array ):
   EX = compute_expectation(x,p)
   x = np.square(x - EX)
   return compute_expectation(x,p)

# %%
def compute_expectation_variance (N: list):
    for n in N:
      print ("N = {val}".format(val = n ))
      # Simulate the rolling of a fair 8-sided die
      q = np.random.randint(low=1,high=9,size=n)
      x,p = np.unique(q,return_counts=True)
      p = p/n
      # Compute Expectation
      EX = compute_expectation(x,p)
      # Compute Variance
      Var = compute_variance(x,p)
      
      print ("Expectation : {ex:.2f} ,  Variance : {var:.2f}".format(ex=EX,var=Var))
 
compute_expectation_variance([100,1000,10000,100000])
# Out:
# N = 100
# Expectation : 4.73 ,  Variance : 5.44
# N = 1000
# Expectation : 4.58 ,  Variance : 5.09
# N = 10000
# Expectation : 4.50 ,  Variance : 5.18
# N = 100000
# Expectation : 4.51 ,  Variance : 5.26

# %% [markdown]
# **Comments**
#
# Rohan Raj
# rr07656
#
# The theoretical values of expaction and variance obtained by considering the outcome of rolling a fair 8-sided die as a Discrete Uniform Random Variable are:
#
#
# Expectation = E(X) = (1+2+3+4+5+6+7+8)/8 = 4.5
#
#
# E(X^2) = (1^2 + 2^2 + 3^2 + 4^2 + 5^2 + 6^2 + 7^2 + 8^2) / 8
#
# = (1 + 4 + 9 + 16 + 25 + 36 + 49 + 64) / 8
#
# = 204 / 8
#
# = 25.5
#
#
# Variance = Var(X) = E(X^2) - (E(X))^2
#
# = 25.5 - (4.5)^2
#
# = 25.5 - 20.25
#
# = 5.25
#
# In the calulations done above using the functions, as we increase the value of N, the resultant values of both expectation and variance become closer to the theoretical values. That means, for greater accuracy, we need to have higher values of N.

# %% [markdown]
# ### Task 3 [25 Marks] : Common Discrete Random Variables ###
# In Task 1, you were introducted to the relationship between histogram and PMF of Random Variables. In Task 2, you were introduced to computing Expectation and Variance. In Task 3, you will be introduced to Common DRVs that you have already discussed in class. The aim of Task 3 is to introduce you to the simulation of these DRVs in Python.

# %% [markdown]
# The following code snippets show you how to simulate the generation of 1000 samples of the following types of random variables: Bernoulli, Binomial, Geometric, Poisson. The code also plots the histogram for the 1000 samples of each type of random variable.

# %%
# Generate 1000 samples of a Bernoulli Random Variable
p = 0.5 # Probability of Success
n = 1   # Number of states (When n = 1, Binomial Random Variable becomes a Bernoulli Random Variable)
size  = 1000 # Number of trials
X = np.random.binomial(n,p,size=size)
plt.title("Bernoulli Random Variable (p=0.5)")
plt.hist(X,bins='auto')
plt.show()

# %%
# Generate 1000 samples of a Binomial Random Variable
p = 0.5 # Probability of a single success
n = 10  # Number of states
size  = 1000 # Number of trials
X = np.random.binomial(n,p,size=size)
plt.title("Binomial Random Variable (n=10, p=0.5)")
plt.hist(X,bins="auto");
plt.show()

# %%
# Generate 1000 samples of a Geometric Random variables
p = 0.5
size = 1000
plt.title("Geometric Random Variable (p = 0.5)")
X = np.random.geometric(p,size=size)
plt.hist(X,bins="auto")
plt.show()

# %%
# Generate 1000 samples of a Poisson Random Variable
lambd = 1
X = np.random.poisson(lambd,size=1000)
plt.title("Poisson Random Variable (lambda = 1)")
plt.hist(X,bins="auto")
plt.show()

# %% [markdown]
# In this task, you are required to vary parameters for each Discrete RV (Bernoulli, Binormail, Geometric, Poission) while keeping others constant and comment on how does this affect the shape of the their histogram.

# %%
# BERNOULLI RANDOM VARIABLE

# Name: Rohan Raj
# ID: rr07656

# Generate 1000 samples of a Bernoulli Random Variable
p = 0.25 # Probability of Success
n = 1   # Number of states (When n = 1, Binomial Random Variable becomes a Bernoulli Random Variable)
size  = 1000 # Number of trials
X = np.random.binomial(n,p,size=size)
plt.title("Bernoulli Random Variable (p=0.25)")
plt.hist(X,bins='auto')
plt.show()

# Generate 1000 samples of a Bernoulli Random Variable
p = 0.75 # Probability of Success
n = 1   # Number of states (When n = 1, Binomial Random Variable becomes a Bernoulli Random Variable)
size  = 1000 # Number of trials
X = np.random.binomial(n,p,size=size)
plt.title("Bernoulli Random Variable (p=0.75)")
plt.hist(X,bins='auto')
plt.show()

# %% [markdown]
# **Comments**
#
#
# Rohan Raj
# rr07656
#
# As we increase the value of p, the height of the bar near 1.0 increases and vice versa. This is because the probability of success increases as the value of p increases.

# %%
# BINOMIAL RANDOM VARIABLE

# Name: Rohan Raj
# ID: rr07656

# Generate 1000 samples of a Binomial Random Variable
p = 0.25 # Probability of a single success
n = 10  # Number of states
size  = 1000 # Number of trials
X = np.random.binomial(n,p,size=size)
plt.title("Binomial Random Variable (n=10, p=0.25)")
plt.hist(X,bins="auto");
plt.show()

# Generate 1000 samples of a Binomial Random Variable
p = 0.75 # Probability of a single success
n = 10  # Number of states
size  = 1000 # Number of trials
X = np.random.binomial(n,p,size=size)
plt.title("Binomial Random Variable (n=10, p=0.75)")
plt.hist(X,bins="auto");
plt.show()

# Generate 1000 samples of a Binomial Random Variable
p = 0.5 # Probability of a single success
n = 20  # Number of states
size  = 1000 # Number of trials
X = np.random.binomial(n,p,size=size)
plt.title("Binomial Random Variable (n=20, p=0.5)")
plt.hist(X,bins="auto");
plt.show()

# Generate 1000 samples of a Binomial Random Variable
p = 0.5 # Probability of a single success
n = 50  # Number of states
size  = 1000 # Number of trials
X = np.random.binomial(n,p,size=size)
plt.title("Binomial Random Variable (n=50, p=0.5)")
plt.hist(X,bins="auto");
plt.show()

# %% [markdown]
# **Comments**
#
#
# Rohan Raj
# rr07656
#
# As we increase the value of p (probability of success), the histogram shifts towards the right, which means distribution is more concentrated around larger values of X
#
# As we increase the number of states, the histogram becomes more compressed.

# %%
# GEOMETRIC RANDOM VARIABLE

# Name: Rohan Raj
# ID: rr07656

# Generate 1000 samples of a Geometric Random variables
p = 0.25
size = 1000
plt.title("Geometric Random Variable (p = 0.25)")
X = np.random.geometric(p,size=size)
plt.hist(X,bins="auto")
plt.show()

# Generate 1000 samples of a Geometric Random variables
p = 0.75
size = 1000
plt.title("Geometric Random Variable (p = 0.75)")
X = np.random.geometric(p,size=size)
plt.hist(X,bins="auto")
plt.show()

# %% [markdown]
# **Comments**
#
#
# Rohan Raj
# rr07656
#
# As we increase the probability of success, the probability mass shifts to the left. Hence, the distribution is more concentrated around smaller values of X and vice versa

# %%
# POISSON RANDOM VARIABLE

# Name: Rohan Raj
# ID: rr07656

# Generate 1000 samples of a Poisson Random Variable
lambd = 5
X = np.random.poisson(lambd,size=1000)
plt.title("Poisson Random Variable (lambda = 5)")
plt.hist(X,bins="auto")
plt.show()

# Generate 1000 samples of a Poisson Random Variable
lambd = 16
X = np.random.poisson(lambd,size=1000)
plt.title("Poisson Random Variable (lambda = 16)")
plt.hist(X,bins="auto")
plt.show()

# Generate 1000 samples of a Poisson Random Variable
lambd = 24
X = np.random.poisson(lambd,size=1000)
plt.title("Poisson Random Variable (lambda = 24)")
plt.hist(X,bins="auto")
plt.show()

# Generate 1000 samples of a Poisson Random Variable
lambd = 64
X = np.random.poisson(lambd,size=1000)
plt.title("Poisson Random Variable (lambda = 64)")
plt.hist(X,bins="auto")
plt.show()

# %% [markdown]
# **Comments**
#
#
# Rohan Raj
# rr07656
#
# As we increase the value of lambda, the histogram becomes more compressed
